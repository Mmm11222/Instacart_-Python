# %% [markdown]
# # Table of contents
#
# ## Importing libraries
# ## Importing data
# ## Grouping data
# ## Aggregating variables

# %% [markdown]
# # Import libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Answer 1

# %%
path = r'C:\Users\Mafalda\Documents\mafalda\Formação\Data Analytics\CareerFoundry\Data Analytics Program\2.Data Immersion\Achievement 4\Instacart Basket Analysis'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data','orders_products_merged_v2.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32434212, 19)

# %%
df_ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'Price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day', 'max_order', 'loyalty_flag'],
#       dtype='object')

# %% [markdown]
# # Answer 2

# %%
# Grouping dataframe by product_ name column
df_ords_prods_merge.groupby('product_name')

# %%
# Aggregating data wirh agg()
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
# Checking the same infoo without agg()
df_ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457687
# 2     17.277920
# 3     17.179756
# 4     17.811403
# 5     15.213779
# 6     16.439806
# 7     17.225773
# 8     15.340520
# 9     15.895474
# 10    20.197148
# 11    16.170828
# 12    15.887622
# 13    16.583304
# 14    16.757377
# 15    16.165037
# 16    17.663250
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
# Checking mean, max and min on the order_number column
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457687   1  99
# 2                17.277920   1  99
# 3                17.179756   1  99
# 4                17.811403   1  99
# 5                15.213779   1  99
# 6                16.439806   1  99
# 7                17.225773   1  99
# 8                15.340520   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170828   1  99
# 12               15.887622   1  99
# 13               16.583304   1  99
# 14               16.757377   1  99
# 15               16.165037   1  99
# 16               17.663250   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# # Answer 3

# %% [markdown]
# ###### in the subset it was identified ( "department Id"_16 - mean 19,463012; department Id"_17 - mean 11.294069) as the highest and lowest mean values. In the total dataframe ( "department Id"_21 - mean 22.902379; department Id"_5 - mean 15.213779), as expected since it holds all the data records.

# %% [markdown]
# # Answer 4

# %%
# Creating loyalty flag column for exsiting customers usinf transform() and loc() functions
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
# Creating a flag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Printing the frequency of the loyalty _flag column
df_ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # Answer 5

# %%
# performing basic statistics on customer spending habits

df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.388747  1.0  99999.0
# New customer      13.294370  1.0  99999.0
# Regular customer  12.496203  1.0  99999.0

# %%
# From the data we can see that there is not a big difference in the average price numbers between the three categories, but there is visible trend on mean price reduction among returning customers.

# %% [markdown]
# # Answer 6

# %%
# Creating a new column for "mean price" for product price range
df_ords_prods_merge['mean_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merge. columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'Price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'mean price'],
#       dtype='object')

# %%
# Creating a Spending flag 
df_ords_prods_merge.loc[df_ords_prods_merge['mean_price'] < 10, 'Spending_flag'] = 'Low spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['mean_price'] >= 10, 'Spending_flag'] = 'High spender'

# %%
# Printing the frequency of the Spending_flag column
df_ords_prods_merge['Spending_flag'].value_counts(dropna=False)
# Out:
# Spending_flag
# Low Spender     31798751
# High spender      635461
# Name: count, dtype: int64

# %%
df_ords_prods_merge. head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ... prices     Price_range_loc     busiest_day  \
# ...

# %% [markdown]
# # Answer 7

# %%
# Creating a median " days_since_prior_order" column
df_ords_prods_merge['median_days_since_prior_order'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merge. head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...     Price_range_loc     busiest_day         busiest_days  \
# ...

# %%
# Creating a Frequency_flag column
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_since_prior_order'] > 20, 'Frequency_flag'] = 'Non-frequent customer"'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_since_prior_order'] > 10) & (df_ords_prods_merge['median_days_since_prior_order'] <= 20) , 'Frequency_flag'] = 'Regular customer"'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_since_prior_order'] <= 10, 'Frequency_flag'] = 'Frequent customer"'

# %%
# Printing the frequency of the Frequency_flag column
df_ords_prods_merge['Frequency_flag'].value_counts(dropna=False)
# Out:
# Frequency_flag
# Frequent customer"        21577409
# Regular customer"          7217134
# Non-frequent customer"     3639669
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...     busiest_day         busiest_days  busiest_period_of_day  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32434212, 26)

# %% [markdown]
# # Answer 9

# %%
# Exporting new dataframe as a pickle file
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_v3.pkl'))
